# %% [markdown]
# #Task 2: Exploring and Visualizing a Simple Dataset
# 1. Introduction
# Problem Statement
#
# The objective of this task is to explore, summarize, and visualize a dataset to better understand relationships between variables and the distribution of data. Visualization helps identify patterns, trends, and outliers, which are essential for effective data analysis.

# %% [markdown]
# #2. Dataset Description
#
# The Iris Dataset is used for this task.
# It contains 150 records of iris flowers with four numerical features and one categorical target variable (species).

# %% [markdown]
# #3. Import Required Libraries

# %%
# Import pandas for data handling
import pandas as pd

# Import matplotlib for basic plotting
import matplotlib.pyplot as plt

# Import seaborn for advanced and styled visualizations
import seaborn as sns

# %% [markdown]
# #4. Load the Dataset

# %%
import pandas as pd

df = pd.read_csv("Iris (1).csv")

# %% [markdown]
# #5. Dataset Inspection

# %%
# Display the number of rows and columns
df.shape

# Display column names
df.columns

# Display the first five rows of the dataset
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #6. Data Summary

# %%
# Display statistical summary of numerical columns
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #7. Data Visualization
# 7.1 Scatter Plot

# %%
# Create a scatter plot to visualize relationship between sepal length and sepal width
plt.figure(figsize=(8, 5))
sns.scatterplot(
    x="SepalLengthCm",
    y="SepalWidthCm",
    hue="Species",
    data=df
)
plt.title("Sepal LengthCm vs Sepal WidthCm")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %% [markdown]
# #7.2 Histogram

# %%
# Create a histogram to show distribution of petal length
plt.figure(figsize=(8, 5))
plt.hist(df["PetalLengthCm"], bins=20)
plt.title("Distribution of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #

# %% [markdown]
# #7.3 Box Plot

# %%
# Create a box plot to detect outliers in petal width
plt.figure(figsize=(8, 5))
sns.boxplot(x="Species", y="PetalWidthCm", data=df)
plt.title("Petal Width Distribution by Species")
plt.xlabel("Species")
plt.ylabel("Petal Width")
plt.show()
